# %%
import pandas as pd
df = pd.read_csv("/content/Titanic-Dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#fllling missing values with ffill for age
df['Age'].fillna(method='ffill', inplace=True)
# Out:
# <ipython-input-3-cdb142793890>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(method='ffill', inplace=True)
# <ipython-input-3-cdb142793890>:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Age'].fillna(method='ffill', inplace=True)

# %%
#filling missing values with bfill for cabin
df['Cabin'].fillna(method='ffill', inplace=True)
# Out:
# <ipython-input-5-62e79f33c6e6>:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Cabin'].fillna(method='ffill', inplace=True)

# %%
#filling missing values with ffill for embarked
df['Embarked'].fillna(method='ffill', inplace=True)
# Out:
# <ipython-input-6-5cf40e4b55a1>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna(method='ffill', inplace=True)
# <ipython-input-6-5cf40e4b55a1>:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Embarked'].fillna(method='ffill', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#checking for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import seaborn as sns
sns.boxplot(df["Fare"])
# Out:
# <Axes: ylabel='Fare'>

# %%
#handling outliers using iqr method
Q1 = df['Fare'].quantile(0.25)
Q3 = df['Fare'].quantile(0.75)
IQR = Q3 - Q1

# %%
upper_bound = Q3 + 1.5 * IQR
lower_bound = Q1 - 1.5 * IQR

# %%
df = df[(df['Fare'] >= lower_bound) & (df['Fare'] <= upper_bound)]

# %%
sns.boxplot(df["Fare"])
# Out:
# <Axes: ylabel='Fare'>

# %% [markdown]
# #Univariate analysis

# %%
sns.countplot(df["Sex"])
# Out:
# <Axes: xlabel='count', ylabel='Sex'>

# %%
sns.countplot(x="Survived", data = df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a countplot
sns.countplot(x='Survived', hue='Sex', data=df)
plt.title('Survival Count by Gender')
plt.xlabel('Survived (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.show()

# %%
#feature engineering
def categorize_age(age):
  if age < 18:
    return 'Minor'
  elif age < 60:
    return 'Major'
  else:
    return 'Senior Citizen'

df['AgeCategory'] = df['Age'].apply(categorize_age)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                       Braund, Mr. Owen Harris    male  22.0      1      0
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked AgeCategory
# 0         A/5 21171   7.2500   C85        S       Major
# 2  STON/O2. 3101282   7.9250  C123        S       Major
# 3            113803  53.1000  C123        S       Major
# 4            373450   8.0500   E46        S       Major
# ...

# %%
sns.countplot(df["AgeCategory"])
# Out:
# <Axes: xlabel='count', ylabel='AgeCategory'>

# %%
sns.countplot(df['Embarked'])
# Out:
# <Axes: xlabel='count', ylabel='Embarked'>

# %%
# Assuming 'Pclass' is a categorical column
sns.countplot(x='Pclass', data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x='SibSp', data=df)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %% [markdown]
# #Multivariate analysis

# %%
sns.scatterplot(x='Age', y='Fare', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(x='Age', y='Fare', hue='Survived', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(x='Age', y='Fare', hue='Pclass', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(x='Age', y='Fare', hue='Sex', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(x='Age', y='Fare', hue='Embarked', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(x='Age', y='Fare', hue='AgeCategory', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(x='Age', y='Fare', hue='SibSp', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(x='Age', y='Fare', hue='Parch', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %% [markdown]
# #Multivariate analysis

# %%
sns.pairplot(df)
